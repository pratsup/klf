# %% [markdown]
# <a href="https://colab.research.google.com/github/pratsup/klf/blob/main/copy_of_tutorialscrapingtwitterpage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Install Node  js

# %%
# Install Node.js (because tweet-harvest built using Node.js)
# !sudo apt-get update
# !sudo apt-get install -y ca-certificates curl gnupg
# !sudo mkdir -p /etc/apt/keyrings
# !curl -fsSL https://deb.nodesource.com/gpgkey/nodesource-repo.gpg.key | sudo gpg --dearmor -o /etc/apt/keyrings/nodesource.gpg

# !NODE_MAJOR=20 && echo "deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_$NODE_MAJOR.x nodistro main" | sudo tee /etc/apt/sources.list.d/nodesource.list

# !sudo apt-get update
# !sudo apt-get install nodejs -y

# !node -v
# Out:
# Hit:1 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:2 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease [24.3 kB]
# Get:10 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,683 kB]
# Get:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease [24.6 kB]
# Get:12 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,729 kB]
# ...

# %% [markdown]
# ## Import library Python yang dibutuhkan

# %%
import pandas as pd

# %% [markdown]
# ## Buka Aplikasi Twitter dan Dapatkan Token
# Buka X pada browser, login dan pilih titik tiga pada pojok kanan browser, cari more tools dan pilih developer tools, pada bagian Cookies pilih https://x.com, kemudian cari tab Application dan pada list yang ditampilkan pilih auth_token kemudian copy valuenya
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from google.colab import userdata
token=userdata.get('tw_token')

# %% [markdown]
# ## Buat keyword dan limitasi pencarian dan jalankan prosess scraping

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
filename = 'result_coretax_25.csv'
search_keyword = 'coretax since:2025-01-01 until:2025-05-18 lang:id'
limit = 300

# %%
# !npx --yes tweet-harvest@latest -o "{filename}" -s "{search_keyword}" -l {limit} --token "{token}"
# Out:
# ⠙⠹⠸⠼⠴Tweet Harvest [v2.6.1]
#
# Research by Helmi Satria
# Use it for Educational Purposes only!
#
# This script uses Chromium Browser to crawl data from Twitter with your Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
#
# Opening twitter search page...
#
#
# Found existing file ./tweets-data/result_coretax_25.csv, renaming to ./tweets-data/result_coretax_25.old.csv
#
# -- Scrolling... (1)
# Filling in keywords: coretax since:2025-01-01 until:2025-05-18 lang:id
#
#  (2) (3)
#
# Your tweets saved to: /content/tweets-data/result_coretax_25.csv
# Total tweets saved: 19
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/result_coretax_25.csv
# Total tweets saved: 39
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/result_coretax_25.csv
# Total tweets saved: 59
#
# -- Scrolling... (1)
#
# ...

# %% [markdown]
# ## Menampilkan data hasil pencarian

# %%
# Specify the path to your CSV file
file_path = f"tweets-data/{filename}"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path, delimiter=",")

# Display the DataFrame
display(df)
# Out:
#      conversation_id_str                      created_at  favorite_count  \
# 0    1922852528577765766  Thu May 15 03:12:22 +0000 2025               0
# 1    1881235212702564368  Mon Jan 20 07:00:01 +0000 2025              28
# 2    1923268677970931780  Fri May 16 06:46:00 +0000 2025               0
# 3    1922493772417368149  Wed May 14 11:15:30 +0000 2025             162
# 4    1922989744012562584  Thu May 15 12:17:37 +0000 2025               0
# ..                   ...                             ...             ...
# 143  1921508551144464458  Sun May 11 10:11:53 +0000 2025               0
# 144  1922606874886627394  Wed May 14 10:56:13 +0000 2025               0
# 145  1923642329044484423  Sat May 17 07:30:45 +0000 2025               0
# 146  1923777679943475270  Sat May 17 16:43:42 +0000 2025               0
# 147  1923777679943475270  Sat May 17 16:32:13 +0000 2025               1
#
#                                              full_text               id_str  \
# ...

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=df)
# Out:
# https://docs.google.com/spreadsheets/d/1wbicIhbRT2RVu6LLWzgh7O2A_YVcEA8nS6Y6PKyn3aA/edit#gid=0
#         <iframe
#             width="100%"
#             height="600"
#             src="https://docs.google.com/spreadsheets/d/1wbicIhbRT2RVu6LLWzgh7O2A_YVcEA8nS6Y6PKyn3aA/edit?rm=embedded#gid=0"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
